# %%
from model_scoring_func import gen_terms_key
from itertools import combinations
from time import time
from model_analysis import translate_model_code

# %%
number_of_terms = 6

terms_key = gen_terms_key()

cnt = 0

t = time()

for i in combinations(list(range(28)), number_of_terms):
    invalid = False

    for j in i:
        if j >= 7:
            key_1 = terms_key[j][0]
            key_2 = terms_key[j][1]
            if key_1 not in i or key_2 not in i:
                invalid = True
                break
        
    if not invalid:
        cnt += 1
        print translate_model_code(list(i))

print '____________________'
print 'time', time() - t
print 'models', cnt
# Out:
# PVC + filler + FR + stabiliser + DINP + LDH
# PVC + filler + FR + stabiliser + DINP + spherical_filler
# PVC + filler + FR + stabiliser + DINP + PVC*filler
# PVC + filler + FR + stabiliser + DINP + PVC*FR
# PVC + filler + FR + stabiliser + DINP + PVC*stabiliser
# PVC + filler + FR + stabiliser + DINP + PVC*DINP
# PVC + filler + FR + stabiliser + DINP + filler*FR
# PVC + filler + FR + stabiliser + DINP + filler*stabiliser
# PVC + filler + FR + stabiliser + DINP + filler*DINP
# PVC + filler + FR + stabiliser + DINP + FR*stabiliser
# PVC + filler + FR + stabiliser + DINP + FR*DINP
# PVC + filler + FR + stabiliser + DINP + stabiliser*DINP
# PVC + filler + FR + stabiliser + LDH + spherical_filler
# PVC + filler + FR + stabiliser + LDH + PVC*filler
# PVC + filler + FR + stabiliser + LDH + PVC*FR
# PVC + filler + FR + stabiliser + LDH + PVC*stabiliser
# PVC + filler + FR + stabiliser + LDH + PVC*LDH
# PVC + filler + FR + stabiliser + LDH + filler*FR
# PVC + filler + FR + stabiliser + LDH + filler*stabiliser
# PVC + filler + FR + stabiliser + LDH + filler*LDH
# PVC + filler + FR + stabiliser + LDH + FR*stabiliser
# PVC + filler + FR + stabiliser + LDH + FR*LDH
# PVC + filler + FR + stabiliser + LDH + stabiliser*LDH
# PVC + filler + FR + stabiliser + spherical_filler + PVC*filler
# PVC + filler + FR + stabiliser + spherical_filler + PVC*FR
# PVC + filler + FR + stabiliser + spherical_filler + PVC*stabiliser
# PVC + filler + FR + stabiliser + spherical_filler + PVC*spherical_filler
# PVC + filler + FR + stabiliser + spherical_filler + filler*FR
# PVC + filler + FR + stabiliser + spherical_filler + filler*stabiliser
# PVC + filler + FR + stabiliser + spherical_filler + filler*spherical_filler
# PVC + filler + FR + stabiliser + spherical_filler + FR*stabiliser
# PVC + filler + FR + stabiliser + spherical_filler + FR*spherical_filler
# PVC + filler + FR + stabiliser + spherical_filler + stabiliser*spherical_filler
# PVC + filler + FR + stabiliser + PVC*filler + PVC*FR
# PVC + filler + FR + stabiliser + PVC*filler + PVC*stabiliser
# PVC + filler + FR + stabiliser + PVC*filler + filler*FR
# PVC + filler + FR + stabiliser + PVC*filler + filler*stabiliser
# PVC + filler + FR + stabiliser + PVC*filler + FR*stabiliser
# PVC + filler + FR + stabiliser + PVC*FR + PVC*stabiliser
# PVC + filler + FR + stabiliser + PVC*FR + filler*FR
# PVC + filler + FR + stabiliser + PVC*FR + filler*stabiliser
# PVC + filler + FR + stabiliser + PVC*FR + FR*stabiliser
# PVC + filler + FR + stabiliser + PVC*stabiliser + filler*FR
# PVC + filler + FR + stabiliser + PVC*stabiliser + filler*stabiliser
# PVC + filler + FR + stabiliser + PVC*stabiliser + FR*stabiliser
# PVC + filler + FR + stabiliser + filler*FR + filler*stabiliser
# PVC + filler + FR + stabiliser + filler*FR + FR*stabiliser
# PVC + filler + FR + stabiliser + filler*stabiliser + FR*stabiliser
# PVC + filler + FR + DINP + LDH + spherical_filler
# PVC + filler + FR + DINP + LDH + PVC*filler
# PVC + filler + FR + DINP + LDH + PVC*FR
# PVC + filler + FR + DINP + LDH + PVC*DINP
# PVC + filler + FR + DINP + LDH + PVC*LDH
# PVC + filler + FR + DINP + LDH + filler*FR
# PVC + filler + FR + DINP + LDH + filler*DINP
# PVC + filler + FR + DINP + LDH + filler*LDH
# PVC + filler + FR + DINP + LDH + FR*DINP
# PVC + filler + FR + DINP + LDH + FR*LDH
# PVC + filler + FR + DINP + LDH + DINP*LDH
# PVC + filler + FR + DINP + spherical_filler + PVC*filler
# PVC + filler + FR + DINP + spherical_filler + PVC*FR
# PVC + filler + FR + DINP + spherical_filler + PVC*DINP
# PVC + filler + FR + DINP + spherical_filler + PVC*spherical_filler
# PVC + filler + FR + DINP + spherical_filler + filler*FR
# PVC + filler + FR + DINP + spherical_filler + filler*DINP
# PVC + filler + FR + DINP + spherical_filler + filler*spherical_filler
# PVC + filler + FR + DINP + spherical_filler + FR*DINP
# PVC + filler + FR + DINP + spherical_filler + FR*spherical_filler
# PVC + filler + FR + DINP + spherical_filler + DINP*spherical_filler
# PVC + filler + FR + DINP + PVC*filler + PVC*FR
# PVC + filler + FR + DINP + PVC*filler + PVC*DINP
# PVC + filler + FR + DINP + PVC*filler + filler*FR
# PVC + filler + FR + DINP + PVC*filler + filler*DINP
# PVC + filler + FR + DINP + PVC*filler + FR*DINP
# PVC + filler + FR + DINP + PVC*FR + PVC*DINP
# PVC + filler + FR + DINP + PVC*FR + filler*FR
# PVC + filler + FR + DINP + PVC*FR + filler*DINP
# PVC + filler + FR + DINP + PVC*FR + FR*DINP
# PVC + filler + FR + DINP + PVC*DINP + filler*FR
# PVC + filler + FR + DINP + PVC*DINP + filler*DINP
# PVC + filler + FR + DINP + PVC*DINP + FR*DINP
# PVC + filler + FR + DINP + filler*FR + filler*DINP
# PVC + filler + FR + DINP + filler*FR + FR*DINP
# PVC + filler + FR + DINP + filler*DINP + FR*DINP
# PVC + filler + FR + LDH + spherical_filler + PVC*filler
# PVC + filler + FR + LDH + spherical_filler + PVC*FR
# PVC + filler + FR + LDH + spherical_filler + PVC*LDH
# PVC + filler + FR + LDH + spherical_filler + PVC*spherical_filler
# PVC + filler + FR + LDH + spherical_filler + filler*FR
# PVC + filler + FR + LDH + spherical_filler + filler*LDH
# PVC + filler + FR + LDH + spherical_filler + filler*spherical_filler
# PVC + filler + FR + LDH + spherical_filler + FR*LDH
# PVC + filler + FR + LDH + spherical_filler + FR*spherical_filler
# PVC + filler + FR + LDH + spherical_filler + LDH*spherical_filler
# PVC + filler + FR + LDH + PVC*filler + PVC*FR
# PVC + filler + FR + LDH + PVC*filler + PVC*LDH
# PVC + filler + FR + LDH + PVC*filler + filler*FR
# PVC + filler + FR + LDH + PVC*filler + filler*LDH
# PVC + filler + FR + LDH + PVC*filler + FR*LDH
# PVC + filler + FR + LDH + PVC*FR + PVC*LDH
# PVC + filler + FR + LDH + PVC*FR + filler*FR
# PVC + filler + FR + LDH + PVC*FR + filler*LDH
# PVC + filler + FR + LDH + PVC*FR + FR*LDH
# PVC + filler + FR + LDH + PVC*LDH + filler*FR
# PVC + filler + FR + LDH + PVC*LDH + filler*LDH
# PVC + filler + FR + LDH + PVC*LDH + FR*LDH
# PVC + filler + FR + LDH + filler*FR + filler*LDH
# PVC + filler + FR + LDH + filler*FR + FR*LDH
# PVC + filler + FR + LDH + filler*LDH + FR*LDH
# PVC + filler + FR + spherical_filler + PVC*filler + PVC*FR
# PVC + filler + FR + spherical_filler + PVC*filler + PVC*spherical_filler
# PVC + filler + FR + spherical_filler + PVC*filler + filler*FR
# PVC + filler + FR + spherical_filler + PVC*filler + filler*spherical_filler
# PVC + filler + FR + spherical_filler + PVC*filler + FR*spherical_filler
# PVC + filler + FR + spherical_filler + PVC*FR + PVC*spherical_filler
# PVC + filler + FR + spherical_filler + PVC*FR + filler*FR
# PVC + filler + FR + spherical_filler + PVC*FR + filler*spherical_filler
# PVC + filler + FR + spherical_filler + PVC*FR + FR*spherical_filler
# PVC + filler + FR + spherical_filler + PVC*spherical_filler + filler*FR
# PVC + filler + FR + spherical_filler + PVC*spherical_filler + filler*spherical_filler
# PVC + filler + FR + spherical_filler + PVC*spherical_filler + FR*spherical_filler
# PVC + filler + FR + spherical_filler + filler*FR + filler*spherical_filler
# PVC + filler + FR + spherical_filler + filler*FR + FR*spherical_filler
# PVC + filler + FR + spherical_filler + filler*spherical_filler + FR*spherical_filler
# PVC + filler + FR + PVC*filler + PVC*FR + filler*FR
# PVC + filler + stabiliser + DINP + LDH + spherical_filler
# PVC + filler + stabiliser + DINP + LDH + PVC*filler
# PVC + filler + stabiliser + DINP + LDH + PVC*stabiliser
# PVC + filler + stabiliser + DINP + LDH + PVC*DINP
# PVC + filler + stabiliser + DINP + LDH + PVC*LDH
# PVC + filler + stabiliser + DINP + LDH + filler*stabiliser
# PVC + filler + stabiliser + DINP + LDH + filler*DINP
# PVC + filler + stabiliser + DINP + LDH + filler*LDH
# PVC + filler + stabiliser + DINP + LDH + stabiliser*DINP
# PVC + filler + stabiliser + DINP + LDH + stabiliser*LDH
# PVC + filler + stabiliser + DINP + LDH + DINP*LDH
# PVC + filler + stabiliser + DINP + spherical_filler + PVC*filler
# PVC + filler + stabiliser + DINP + spherical_filler + PVC*stabiliser
# PVC + filler + stabiliser + DINP + spherical_filler + PVC*DINP
# PVC + filler + stabiliser + DINP + spherical_filler + PVC*spherical_filler
# PVC + filler + stabiliser + DINP + spherical_filler + filler*stabiliser
# PVC + filler + stabiliser + DINP + spherical_filler + filler*DINP
# PVC + filler + stabiliser + DINP + spherical_filler + filler*spherical_filler
# PVC + filler + stabiliser + DINP + spherical_filler + stabiliser*DINP
# PVC + filler + stabiliser + DINP + spherical_filler + stabiliser*spherical_filler
# PVC + filler + stabiliser + DINP + spherical_filler + DINP*spherical_filler
# PVC + filler + stabiliser + DINP + PVC*filler + PVC*stabiliser
# PVC + filler + stabiliser + DINP + PVC*filler + PVC*DINP
# PVC + filler + stabiliser + DINP + PVC*filler + filler*stabiliser
# PVC + filler + stabiliser + DINP + PVC*filler + filler*DINP
# PVC + filler + stabiliser + DINP + PVC*filler + stabiliser*DINP
# PVC + filler + stabiliser + DINP + PVC*stabiliser + PVC*DINP
# PVC + filler + stabiliser + DINP + PVC*stabiliser + filler*stabiliser
# PVC + filler + stabiliser + DINP + PVC*stabiliser + filler*DINP
# PVC + filler + stabiliser + DINP + PVC*stabiliser + stabiliser*DINP
# PVC + filler + stabiliser + DINP + PVC*DINP + filler*stabiliser
# PVC + filler + stabiliser + DINP + PVC*DINP + filler*DINP
# PVC + filler + stabiliser + DINP + PVC*DINP + stabiliser*DINP
# PVC + filler + stabiliser + DINP + filler*stabiliser + filler*DINP
# PVC + filler + stabiliser + DINP + filler*stabiliser + stabiliser*DINP
# PVC + filler + stabiliser + DINP + filler*DINP + stabiliser*DINP
# PVC + filler + stabiliser + LDH + spherical_filler + PVC*filler
# PVC + filler + stabiliser + LDH + spherical_filler + PVC*stabiliser
# PVC + filler + stabiliser + LDH + spherical_filler + PVC*LDH
# PVC + filler + stabiliser + LDH + spherical_filler + PVC*spherical_filler
# PVC + filler + stabiliser + LDH + spherical_filler + filler*stabiliser
# PVC + filler + stabiliser + LDH + spherical_filler + filler*LDH
# PVC + filler + stabiliser + LDH + spherical_filler + filler*spherical_filler
# PVC + filler + stabiliser + LDH + spherical_filler + stabiliser*LDH
# PVC + filler + stabiliser + LDH + spherical_filler + stabiliser*spherical_filler
# PVC + filler + stabiliser + LDH + spherical_filler + LDH*spherical_filler
# PVC + filler + stabiliser + LDH + PVC*filler + PVC*stabiliser
# PVC + filler + stabiliser + LDH + PVC*filler + PVC*LDH
# PVC + filler + stabiliser + LDH + PVC*filler + filler*stabiliser
# PVC + filler + stabiliser + LDH + PVC*filler + filler*LDH
# PVC + filler + stabiliser + LDH + PVC*filler + stabiliser*LDH
# PVC + filler + stabiliser + LDH + PVC*stabiliser + PVC*LDH
# PVC + filler + stabiliser + LDH + PVC*stabiliser + filler*stabiliser
# PVC + filler + stabiliser + LDH + PVC*stabiliser + filler*LDH
# PVC + filler + stabiliser + LDH + PVC*stabiliser + stabiliser*LDH
# PVC + filler + stabiliser + LDH + PVC*LDH + filler*stabiliser
# PVC + filler + stabiliser + LDH + PVC*LDH + filler*LDH
# PVC + filler + stabiliser + LDH + PVC*LDH + stabiliser*LDH
# PVC + filler + stabiliser + LDH + filler*stabiliser + filler*LDH
# PVC + filler + stabiliser + LDH + filler*stabiliser + stabiliser*LDH
# PVC + filler + stabiliser + LDH + filler*LDH + stabiliser*LDH
# PVC + filler + stabiliser + spherical_filler + PVC*filler + PVC*stabiliser
# PVC + filler + stabiliser + spherical_filler + PVC*filler + PVC*spherical_filler
# PVC + filler + stabiliser + spherical_filler + PVC*filler + filler*stabiliser
# PVC + filler + stabiliser + spherical_filler + PVC*filler + filler*spherical_filler
# PVC + filler + stabiliser + spherical_filler + PVC*filler + stabiliser*spherical_filler
# PVC + filler + stabiliser + spherical_filler + PVC*stabiliser + PVC*spherical_filler
# PVC + filler + stabiliser + spherical_filler + PVC*stabiliser + filler*stabiliser
# PVC + filler + stabiliser + spherical_filler + PVC*stabiliser + filler*spherical_filler
# PVC + filler + stabiliser + spherical_filler + PVC*stabiliser + stabiliser*spherical_filler
# PVC + filler + stabiliser + spherical_filler + PVC*spherical_filler + filler*stabiliser
# PVC + filler + stabiliser + spherical_filler + PVC*spherical_filler + filler*spherical_filler
# PVC + filler + stabiliser + spherical_filler + PVC*spherical_filler + stabiliser*spherical_filler
# PVC + filler + stabiliser + spherical_filler + filler*stabiliser + filler*spherical_filler
# PVC + filler + stabiliser + spherical_filler + filler*stabiliser + stabiliser*spherical_filler
# PVC + filler + stabiliser + spherical_filler + filler*spherical_filler + stabiliser*spherical_filler
# PVC + filler + stabiliser + PVC*filler + PVC*stabiliser + filler*stabiliser
# PVC + filler + DINP + LDH + spherical_filler + PVC*filler
# PVC + filler + DINP + LDH + spherical_filler + PVC*DINP
# PVC + filler + DINP + LDH + spherical_filler + PVC*LDH
# PVC + filler + DINP + LDH + spherical_filler + PVC*spherical_filler
# PVC + filler + DINP + LDH + spherical_filler + filler*DINP
# PVC + filler + DINP + LDH + spherical_filler + filler*LDH
# PVC + filler + DINP + LDH + spherical_filler + filler*spherical_filler
# PVC + filler + DINP + LDH + spherical_filler + DINP*LDH
# PVC + filler + DINP + LDH + spherical_filler + DINP*spherical_filler
# PVC + filler + DINP + LDH + spherical_filler + LDH*spherical_filler
# PVC + filler + DINP + LDH + PVC*filler + PVC*DINP
# PVC + filler + DINP + LDH + PVC*filler + PVC*LDH
# PVC + filler + DINP + LDH + PVC*filler + filler*DINP
# PVC + filler + DINP + LDH + PVC*filler + filler*LDH
# PVC + filler + DINP + LDH + PVC*filler + DINP*LDH
# PVC + filler + DINP + LDH + PVC*DINP + PVC*LDH
# PVC + filler + DINP + LDH + PVC*DINP + filler*DINP
# PVC + filler + DINP + LDH + PVC*DINP + filler*LDH
# PVC + filler + DINP + LDH + PVC*DINP + DINP*LDH
# PVC + filler + DINP + LDH + PVC*LDH + filler*DINP
# PVC + filler + DINP + LDH + PVC*LDH + filler*LDH
# PVC + filler + DINP + LDH + PVC*LDH + DINP*LDH
# PVC + filler + DINP + LDH + filler*DINP + filler*LDH
# PVC + filler + DINP + LDH + filler*DINP + DINP*LDH
# PVC + filler + DINP + LDH + filler*LDH + DINP*LDH
# PVC + filler + DINP + spherical_filler + PVC*filler + PVC*DINP
# PVC + filler + DINP + spherical_filler + PVC*filler + PVC*spherical_filler
# PVC + filler + DINP + spherical_filler + PVC*filler + filler*DINP
# PVC + filler + DINP + spherical_filler + PVC*filler + filler*spherical_filler
# PVC + filler + DINP + spherical_filler + PVC*filler + DINP*spherical_filler
# PVC + filler + DINP + spherical_filler + PVC*DINP + PVC*spherical_filler
# PVC + filler + DINP + spherical_filler + PVC*DINP + filler*DINP
# PVC + filler + DINP + spherical_filler + PVC*DINP + filler*spherical_filler
# PVC + filler + DINP + spherical_filler + PVC*DINP + DINP*spherical_filler
# PVC + filler + DINP + spherical_filler + PVC*spherical_filler + filler*DINP
# PVC + filler + DINP + spherical_filler + PVC*spherical_filler + filler*spherical_filler
# PVC + filler + DINP + spherical_filler + PVC*spherical_filler + DINP*spherical_filler
# PVC + filler + DINP + spherical_filler + filler*DINP + filler*spherical_filler
# PVC + filler + DINP + spherical_filler + filler*DINP + DINP*spherical_filler
# PVC + filler + DINP + spherical_filler + filler*spherical_filler + DINP*spherical_filler
# PVC + filler + DINP + PVC*filler + PVC*DINP + filler*DINP
# PVC + filler + LDH + spherical_filler + PVC*filler + PVC*LDH
# PVC + filler + LDH + spherical_filler + PVC*filler + PVC*spherical_filler
# PVC + filler + LDH + spherical_filler + PVC*filler + filler*LDH
# PVC + filler + LDH + spherical_filler + PVC*filler + filler*spherical_filler
# PVC + filler + LDH + spherical_filler + PVC*filler + LDH*spherical_filler
# PVC + filler + LDH + spherical_filler + PVC*LDH + PVC*spherical_filler
# PVC + filler + LDH + spherical_filler + PVC*LDH + filler*LDH
# PVC + filler + LDH + spherical_filler + PVC*LDH + filler*spherical_filler
# PVC + filler + LDH + spherical_filler + PVC*LDH + LDH*spherical_filler
# PVC + filler + LDH + spherical_filler + PVC*spherical_filler + filler*LDH
# PVC + filler + LDH + spherical_filler + PVC*spherical_filler + filler*spherical_filler
# PVC + filler + LDH + spherical_filler + PVC*spherical_filler + LDH*spherical_filler
# PVC + filler + LDH + spherical_filler + filler*LDH + filler*spherical_filler
# PVC + filler + LDH + spherical_filler + filler*LDH + LDH*spherical_filler
# PVC + filler + LDH + spherical_filler + filler*spherical_filler + LDH*spherical_filler
# PVC + filler + LDH + PVC*filler + PVC*LDH + filler*LDH
# PVC + filler + spherical_filler + PVC*filler + PVC*spherical_filler + filler*spherical_filler
# PVC + FR + stabiliser + DINP + LDH + spherical_filler
# PVC + FR + stabiliser + DINP + LDH + PVC*FR
# PVC + FR + stabiliser + DINP + LDH + PVC*stabiliser
# PVC + FR + stabiliser + DINP + LDH + PVC*DINP
# PVC + FR + stabiliser + DINP + LDH + PVC*LDH
# PVC + FR + stabiliser + DINP + LDH + FR*stabiliser
# PVC + FR + stabiliser + DINP + LDH + FR*DINP
# PVC + FR + stabiliser + DINP + LDH + FR*LDH
# PVC + FR + stabiliser + DINP + LDH + stabiliser*DINP
# PVC + FR + stabiliser + DINP + LDH + stabiliser*LDH
# PVC + FR + stabiliser + DINP + LDH + DINP*LDH
# PVC + FR + stabiliser + DINP + spherical_filler + PVC*FR
# PVC + FR + stabiliser + DINP + spherical_filler + PVC*stabiliser
# PVC + FR + stabiliser + DINP + spherical_filler + PVC*DINP
# PVC + FR + stabiliser + DINP + spherical_filler + PVC*spherical_filler
# PVC + FR + stabiliser + DINP + spherical_filler + FR*stabiliser
# PVC + FR + stabiliser + DINP + spherical_filler + FR*DINP
# PVC + FR + stabiliser + DINP + spherical_filler + FR*spherical_filler
# PVC + FR + stabiliser + DINP + spherical_filler + stabiliser*DINP
# PVC + FR + stabiliser + DINP + spherical_filler + stabiliser*spherical_filler
# PVC + FR + stabiliser + DINP + spherical_filler + DINP*spherical_filler
# PVC + FR + stabiliser + DINP + PVC*FR + PVC*stabiliser
# PVC + FR + stabiliser + DINP + PVC*FR + PVC*DINP
# PVC + FR + stabiliser + DINP + PVC*FR + FR*stabiliser
# PVC + FR + stabiliser + DINP + PVC*FR + FR*DINP
# PVC + FR + stabiliser + DINP + PVC*FR + stabiliser*DINP
# PVC + FR + stabiliser + DINP + PVC*stabiliser + PVC*DINP
# PVC + FR + stabiliser + DINP + PVC*stabiliser + FR*stabiliser
# PVC + FR + stabiliser + DINP + PVC*stabiliser + FR*DINP
# PVC + FR + stabiliser + DINP + PVC*stabiliser + stabiliser*DINP
# PVC + FR + stabiliser + DINP + PVC*DINP + FR*stabiliser
# PVC + FR + stabiliser + DINP + PVC*DINP + FR*DINP
# PVC + FR + stabiliser + DINP + PVC*DINP + stabiliser*DINP
# PVC + FR + stabiliser + DINP + FR*stabiliser + FR*DINP
# PVC + FR + stabiliser + DINP + FR*stabiliser + stabiliser*DINP
# PVC + FR + stabiliser + DINP + FR*DINP + stabiliser*DINP
# PVC + FR + stabiliser + LDH + spherical_filler + PVC*FR
# PVC + FR + stabiliser + LDH + spherical_filler + PVC*stabiliser
# PVC + FR + stabiliser + LDH + spherical_filler + PVC*LDH
# PVC + FR + stabiliser + LDH + spherical_filler + PVC*spherical_filler
# PVC + FR + stabiliser + LDH + spherical_filler + FR*stabiliser
# PVC + FR + stabiliser + LDH + spherical_filler + FR*LDH
# PVC + FR + stabiliser + LDH + spherical_filler + FR*spherical_filler
# PVC + FR + stabiliser + LDH + spherical_filler + stabiliser*LDH
# PVC + FR + stabiliser + LDH + spherical_filler + stabiliser*spherical_filler
# PVC + FR + stabiliser + LDH + spherical_filler + LDH*spherical_filler
# PVC + FR + stabiliser + LDH + PVC*FR + PVC*stabiliser
# PVC + FR + stabiliser + LDH + PVC*FR + PVC*LDH
# PVC + FR + stabiliser + LDH + PVC*FR + FR*stabiliser
# PVC + FR + stabiliser + LDH + PVC*FR + FR*LDH
# PVC + FR + stabiliser + LDH + PVC*FR + stabiliser*LDH
# PVC + FR + stabiliser + LDH + PVC*stabiliser + PVC*LDH
# PVC + FR + stabiliser + LDH + PVC*stabiliser + FR*stabiliser
# PVC + FR + stabiliser + LDH + PVC*stabiliser + FR*LDH
# PVC + FR + stabiliser + LDH + PVC*stabiliser + stabiliser*LDH
# PVC + FR + stabiliser + LDH + PVC*LDH + FR*stabiliser
# PVC + FR + stabiliser + LDH + PVC*LDH + FR*LDH
# PVC + FR + stabiliser + LDH + PVC*LDH + stabiliser*LDH
# PVC + FR + stabiliser + LDH + FR*stabiliser + FR*LDH
# PVC + FR + stabiliser + LDH + FR*stabiliser + stabiliser*LDH
# PVC + FR + stabiliser + LDH + FR*LDH + stabiliser*LDH
# PVC + FR + stabiliser + spherical_filler + PVC*FR + PVC*stabiliser
# PVC + FR + stabiliser + spherical_filler + PVC*FR + PVC*spherical_filler
# PVC + FR + stabiliser + spherical_filler + PVC*FR + FR*stabiliser
# PVC + FR + stabiliser + spherical_filler + PVC*FR + FR*spherical_filler
# PVC + FR + stabiliser + spherical_filler + PVC*FR + stabiliser*spherical_filler
# PVC + FR + stabiliser + spherical_filler + PVC*stabiliser + PVC*spherical_filler
# PVC + FR + stabiliser + spherical_filler + PVC*stabiliser + FR*stabiliser
# PVC + FR + stabiliser + spherical_filler + PVC*stabiliser + FR*spherical_filler
# PVC + FR + stabiliser + spherical_filler + PVC*stabiliser + stabiliser*spherical_filler
# PVC + FR + stabiliser + spherical_filler + PVC*spherical_filler + FR*stabiliser
# PVC + FR + stabiliser + spherical_filler + PVC*spherical_filler + FR*spherical_filler
# PVC + FR + stabiliser + spherical_filler + PVC*spherical_filler + stabiliser*spherical_filler
# PVC + FR + stabiliser + spherical_filler + FR*stabiliser + FR*spherical_filler
# PVC + FR + stabiliser + spherical_filler + FR*stabiliser + stabiliser*spherical_filler
# PVC + FR + stabiliser + spherical_filler + FR*spherical_filler + stabiliser*spherical_filler
# PVC + FR + stabiliser + PVC*FR + PVC*stabiliser + FR*stabiliser
# PVC + FR + DINP + LDH + spherical_filler + PVC*FR
# PVC + FR + DINP + LDH + spherical_filler + PVC*DINP
# PVC + FR + DINP + LDH + spherical_filler + PVC*LDH
# PVC + FR + DINP + LDH + spherical_filler + PVC*spherical_filler
# PVC + FR + DINP + LDH + spherical_filler + FR*DINP
# PVC + FR + DINP + LDH + spherical_filler + FR*LDH
# PVC + FR + DINP + LDH + spherical_filler + FR*spherical_filler
# PVC + FR + DINP + LDH + spherical_filler + DINP*LDH
# PVC + FR + DINP + LDH + spherical_filler + DINP*spherical_filler
# PVC + FR + DINP + LDH + spherical_filler + LDH*spherical_filler
# PVC + FR + DINP + LDH + PVC*FR + PVC*DINP
# PVC + FR + DINP + LDH + PVC*FR + PVC*LDH
# PVC + FR + DINP + LDH + PVC*FR + FR*DINP
# PVC + FR + DINP + LDH + PVC*FR + FR*LDH
# PVC + FR + DINP + LDH + PVC*FR + DINP*LDH
# PVC + FR + DINP + LDH + PVC*DINP + PVC*LDH
# PVC + FR + DINP + LDH + PVC*DINP + FR*DINP
# PVC + FR + DINP + LDH + PVC*DINP + FR*LDH
# PVC + FR + DINP + LDH + PVC*DINP + DINP*LDH
# PVC + FR + DINP + LDH + PVC*LDH + FR*DINP
# PVC + FR + DINP + LDH + PVC*LDH + FR*LDH
# PVC + FR + DINP + LDH + PVC*LDH + DINP*LDH
# PVC + FR + DINP + LDH + FR*DINP + FR*LDH
# PVC + FR + DINP + LDH + FR*DINP + DINP*LDH
# PVC + FR + DINP + LDH + FR*LDH + DINP*LDH
# PVC + FR + DINP + spherical_filler + PVC*FR + PVC*DINP
# PVC + FR + DINP + spherical_filler + PVC*FR + PVC*spherical_filler
# PVC + FR + DINP + spherical_filler + PVC*FR + FR*DINP
# PVC + FR + DINP + spherical_filler + PVC*FR + FR*spherical_filler
# PVC + FR + DINP + spherical_filler + PVC*FR + DINP*spherical_filler
# PVC + FR + DINP + spherical_filler + PVC*DINP + PVC*spherical_filler
# PVC + FR + DINP + spherical_filler + PVC*DINP + FR*DINP
# PVC + FR + DINP + spherical_filler + PVC*DINP + FR*spherical_filler
# PVC + FR + DINP + spherical_filler + PVC*DINP + DINP*spherical_filler
# PVC + FR + DINP + spherical_filler + PVC*spherical_filler + FR*DINP
# PVC + FR + DINP + spherical_filler + PVC*spherical_filler + FR*spherical_filler
# PVC + FR + DINP + spherical_filler + PVC*spherical_filler + DINP*spherical_filler
# PVC + FR + DINP + spherical_filler + FR*DINP + FR*spherical_filler
# PVC + FR + DINP + spherical_filler + FR*DINP + DINP*spherical_filler
# PVC + FR + DINP + spherical_filler + FR*spherical_filler + DINP*spherical_filler
# PVC + FR + DINP + PVC*FR + PVC*DINP + FR*DINP
# PVC + FR + LDH + spherical_filler + PVC*FR + PVC*LDH
# PVC + FR + LDH + spherical_filler + PVC*FR + PVC*spherical_filler
# PVC + FR + LDH + spherical_filler + PVC*FR + FR*LDH
# PVC + FR + LDH + spherical_filler + PVC*FR + FR*spherical_filler
# PVC + FR + LDH + spherical_filler + PVC*FR + LDH*spherical_filler
# PVC + FR + LDH + spherical_filler + PVC*LDH + PVC*spherical_filler
# PVC + FR + LDH + spherical_filler + PVC*LDH + FR*LDH
# PVC + FR + LDH + spherical_filler + PVC*LDH + FR*spherical_filler
# PVC + FR + LDH + spherical_filler + PVC*LDH + LDH*spherical_filler
# PVC + FR + LDH + spherical_filler + PVC*spherical_filler + FR*LDH
# PVC + FR + LDH + spherical_filler + PVC*spherical_filler + FR*spherical_filler
# PVC + FR + LDH + spherical_filler + PVC*spherical_filler + LDH*spherical_filler
# PVC + FR + LDH + spherical_filler + FR*LDH + FR*spherical_filler
# PVC + FR + LDH + spherical_filler + FR*LDH + LDH*spherical_filler
# PVC + FR + LDH + spherical_filler + FR*spherical_filler + LDH*spherical_filler
# PVC + FR + LDH + PVC*FR + PVC*LDH + FR*LDH
# PVC + FR + spherical_filler + PVC*FR + PVC*spherical_filler + FR*spherical_filler
# PVC + stabiliser + DINP + LDH + spherical_filler + PVC*stabiliser
# PVC + stabiliser + DINP + LDH + spherical_filler + PVC*DINP
# PVC + stabiliser + DINP + LDH + spherical_filler + PVC*LDH
# PVC + stabiliser + DINP + LDH + spherical_filler + PVC*spherical_filler
# PVC + stabiliser + DINP + LDH + spherical_filler + stabiliser*DINP
# PVC + stabiliser + DINP + LDH + spherical_filler + stabiliser*LDH
# PVC + stabiliser + DINP + LDH + spherical_filler + stabiliser*spherical_filler
# PVC + stabiliser + DINP + LDH + spherical_filler + DINP*LDH
# PVC + stabiliser + DINP + LDH + spherical_filler + DINP*spherical_filler
# PVC + stabiliser + DINP + LDH + spherical_filler + LDH*spherical_filler
# PVC + stabiliser + DINP + LDH + PVC*stabiliser + PVC*DINP
# PVC + stabiliser + DINP + LDH + PVC*stabiliser + PVC*LDH
# PVC + stabiliser + DINP + LDH + PVC*stabiliser + stabiliser*DINP
# PVC + stabiliser + DINP + LDH + PVC*stabiliser + stabiliser*LDH
# PVC + stabiliser + DINP + LDH + PVC*stabiliser + DINP*LDH
# PVC + stabiliser + DINP + LDH + PVC*DINP + PVC*LDH
# PVC + stabiliser + DINP + LDH + PVC*DINP + stabiliser*DINP
# PVC + stabiliser + DINP + LDH + PVC*DINP + stabiliser*LDH
# PVC + stabiliser + DINP + LDH + PVC*DINP + DINP*LDH
# PVC + stabiliser + DINP + LDH + PVC*LDH + stabiliser*DINP
# PVC + stabiliser + DINP + LDH + PVC*LDH + stabiliser*LDH
# PVC + stabiliser + DINP + LDH + PVC*LDH + DINP*LDH
# PVC + stabiliser + DINP + LDH + stabiliser*DINP + stabiliser*LDH
# PVC + stabiliser + DINP + LDH + stabiliser*DINP + DINP*LDH
# PVC + stabiliser + DINP + LDH + stabiliser*LDH + DINP*LDH
# PVC + stabiliser + DINP + spherical_filler + PVC*stabiliser + PVC*DINP
# PVC + stabiliser + DINP + spherical_filler + PVC*stabiliser + PVC*spherical_filler
# PVC + stabiliser + DINP + spherical_filler + PVC*stabiliser + stabiliser*DINP
# PVC + stabiliser + DINP + spherical_filler + PVC*stabiliser + stabiliser*spherical_filler
# PVC + stabiliser + DINP + spherical_filler + PVC*stabiliser + DINP*spherical_filler
# PVC + stabiliser + DINP + spherical_filler + PVC*DINP + PVC*spherical_filler
# PVC + stabiliser + DINP + spherical_filler + PVC*DINP + stabiliser*DINP
# PVC + stabiliser + DINP + spherical_filler + PVC*DINP + stabiliser*spherical_filler
# PVC + stabiliser + DINP + spherical_filler + PVC*DINP + DINP*spherical_filler
# PVC + stabiliser + DINP + spherical_filler + PVC*spherical_filler + stabiliser*DINP
# PVC + stabiliser + DINP + spherical_filler + PVC*spherical_filler + stabiliser*spherical_filler
# PVC + stabiliser + DINP + spherical_filler + PVC*spherical_filler + DINP*spherical_filler
# PVC + stabiliser + DINP + spherical_filler + stabiliser*DINP + stabiliser*spherical_filler
# PVC + stabiliser + DINP + spherical_filler + stabiliser*DINP + DINP*spherical_filler
# PVC + stabiliser + DINP + spherical_filler + stabiliser*spherical_filler + DINP*spherical_filler
# PVC + stabiliser + DINP + PVC*stabiliser + PVC*DINP + stabiliser*DINP
# PVC + stabiliser + LDH + spherical_filler + PVC*stabiliser + PVC*LDH
# PVC + stabiliser + LDH + spherical_filler + PVC*stabiliser + PVC*spherical_filler
# PVC + stabiliser + LDH + spherical_filler + PVC*stabiliser + stabiliser*LDH
# PVC + stabiliser + LDH + spherical_filler + PVC*stabiliser + stabiliser*spherical_filler
# PVC + stabiliser + LDH + spherical_filler + PVC*stabiliser + LDH*spherical_filler
# PVC + stabiliser + LDH + spherical_filler + PVC*LDH + PVC*spherical_filler
# PVC + stabiliser + LDH + spherical_filler + PVC*LDH + stabiliser*LDH
# PVC + stabiliser + LDH + spherical_filler + PVC*LDH + stabiliser*spherical_filler
# PVC + stabiliser + LDH + spherical_filler + PVC*LDH + LDH*spherical_filler
# PVC + stabiliser + LDH + spherical_filler + PVC*spherical_filler + stabiliser*LDH
# PVC + stabiliser + LDH + spherical_filler + PVC*spherical_filler + stabiliser*spherical_filler
# PVC + stabiliser + LDH + spherical_filler + PVC*spherical_filler + LDH*spherical_filler
# PVC + stabiliser + LDH + spherical_filler + stabiliser*LDH + stabiliser*spherical_filler
# PVC + stabiliser + LDH + spherical_filler + stabiliser*LDH + LDH*spherical_filler
# PVC + stabiliser + LDH + spherical_filler + stabiliser*spherical_filler + LDH*spherical_filler
# PVC + stabiliser + LDH + PVC*stabiliser + PVC*LDH + stabiliser*LDH
# PVC + stabiliser + spherical_filler + PVC*stabiliser + PVC*spherical_filler + stabiliser*spherical_filler
# PVC + DINP + LDH + spherical_filler + PVC*DINP + PVC*LDH
# PVC + DINP + LDH + spherical_filler + PVC*DINP + PVC*spherical_filler
# PVC + DINP + LDH + spherical_filler + PVC*DINP + DINP*LDH
# PVC + DINP + LDH + spherical_filler + PVC*DINP + DINP*spherical_filler
# PVC + DINP + LDH + spherical_filler + PVC*DINP + LDH*spherical_filler
# PVC + DINP + LDH + spherical_filler + PVC*LDH + PVC*spherical_filler
# PVC + DINP + LDH + spherical_filler + PVC*LDH + DINP*LDH
# PVC + DINP + LDH + spherical_filler + PVC*LDH + DINP*spherical_filler
# PVC + DINP + LDH + spherical_filler + PVC*LDH + LDH*spherical_filler
# PVC + DINP + LDH + spherical_filler + PVC*spherical_filler + DINP*LDH
# PVC + DINP + LDH + spherical_filler + PVC*spherical_filler + DINP*spherical_filler
# PVC + DINP + LDH + spherical_filler + PVC*spherical_filler + LDH*spherical_filler
# PVC + DINP + LDH + spherical_filler + DINP*LDH + DINP*spherical_filler
# PVC + DINP + LDH + spherical_filler + DINP*LDH + LDH*spherical_filler
# PVC + DINP + LDH + spherical_filler + DINP*spherical_filler + LDH*spherical_filler
# PVC + DINP + LDH + PVC*DINP + PVC*LDH + DINP*LDH
# PVC + DINP + spherical_filler + PVC*DINP + PVC*spherical_filler + DINP*spherical_filler
# PVC + LDH + spherical_filler + PVC*LDH + PVC*spherical_filler + LDH*spherical_filler
# filler + FR + stabiliser + DINP + LDH + spherical_filler
# filler + FR + stabiliser + DINP + LDH + filler*FR
# filler + FR + stabiliser + DINP + LDH + filler*stabiliser
# filler + FR + stabiliser + DINP + LDH + filler*DINP
# filler + FR + stabiliser + DINP + LDH + filler*LDH
# filler + FR + stabiliser + DINP + LDH + FR*stabiliser
# filler + FR + stabiliser + DINP + LDH + FR*DINP
# filler + FR + stabiliser + DINP + LDH + FR*LDH
# filler + FR + stabiliser + DINP + LDH + stabiliser*DINP
# filler + FR + stabiliser + DINP + LDH + stabiliser*LDH
# filler + FR + stabiliser + DINP + LDH + DINP*LDH
# filler + FR + stabiliser + DINP + spherical_filler + filler*FR
# filler + FR + stabiliser + DINP + spherical_filler + filler*stabiliser
# filler + FR + stabiliser + DINP + spherical_filler + filler*DINP
# filler + FR + stabiliser + DINP + spherical_filler + filler*spherical_filler
# filler + FR + stabiliser + DINP + spherical_filler + FR*stabiliser
# filler + FR + stabiliser + DINP + spherical_filler + FR*DINP
# filler + FR + stabiliser + DINP + spherical_filler + FR*spherical_filler
# filler + FR + stabiliser + DINP + spherical_filler + stabiliser*DINP
# filler + FR + stabiliser + DINP + spherical_filler + stabiliser*spherical_filler
# filler + FR + stabiliser + DINP + spherical_filler + DINP*spherical_filler
# filler + FR + stabiliser + DINP + filler*FR + filler*stabiliser
# filler + FR + stabiliser + DINP + filler*FR + filler*DINP
# filler + FR + stabiliser + DINP + filler*FR + FR*stabiliser
# filler + FR + stabiliser + DINP + filler*FR + FR*DINP
# filler + FR + stabiliser + DINP + filler*FR + stabiliser*DINP
# filler + FR + stabiliser + DINP + filler*stabiliser + filler*DINP
# filler + FR + stabiliser + DINP + filler*stabiliser + FR*stabiliser
# filler + FR + stabiliser + DINP + filler*stabiliser + FR*DINP
# filler + FR + stabiliser + DINP + filler*stabiliser + stabiliser*DINP
# filler + FR + stabiliser + DINP + filler*DINP + FR*stabiliser
# filler + FR + stabiliser + DINP + filler*DINP + FR*DINP
# filler + FR + stabiliser + DINP + filler*DINP + stabiliser*DINP
# filler + FR + stabiliser + DINP + FR*stabiliser + FR*DINP
# filler + FR + stabiliser + DINP + FR*stabiliser + stabiliser*DINP
# filler + FR + stabiliser + DINP + FR*DINP + stabiliser*DINP
# filler + FR + stabiliser + LDH + spherical_filler + filler*FR
# filler + FR + stabiliser + LDH + spherical_filler + filler*stabiliser
# filler + FR + stabiliser + LDH + spherical_filler + filler*LDH
# filler + FR + stabiliser + LDH + spherical_filler + filler*spherical_filler
# filler + FR + stabiliser + LDH + spherical_filler + FR*stabiliser
# filler + FR + stabiliser + LDH + spherical_filler + FR*LDH
# filler + FR + stabiliser + LDH + spherical_filler + FR*spherical_filler
# filler + FR + stabiliser + LDH + spherical_filler + stabiliser*LDH
# filler + FR + stabiliser + LDH + spherical_filler + stabiliser*spherical_filler
# filler + FR + stabiliser + LDH + spherical_filler + LDH*spherical_filler
# filler + FR + stabiliser + LDH + filler*FR + filler*stabiliser
# filler + FR + stabiliser + LDH + filler*FR + filler*LDH
# filler + FR + stabiliser + LDH + filler*FR + FR*stabiliser
# filler + FR + stabiliser + LDH + filler*FR + FR*LDH
# filler + FR + stabiliser + LDH + filler*FR + stabiliser*LDH
# filler + FR + stabiliser + LDH + filler*stabiliser + filler*LDH
# filler + FR + stabiliser + LDH + filler*stabiliser + FR*stabiliser
# filler + FR + stabiliser + LDH + filler*stabiliser + FR*LDH
# filler + FR + stabiliser + LDH + filler*stabiliser + stabiliser*LDH
# filler + FR + stabiliser + LDH + filler*LDH + FR*stabiliser
# filler + FR + stabiliser + LDH + filler*LDH + FR*LDH
# filler + FR + stabiliser + LDH + filler*LDH + stabiliser*LDH
# filler + FR + stabiliser + LDH + FR*stabiliser + FR*LDH
# filler + FR + stabiliser + LDH + FR*stabiliser + stabiliser*LDH
# filler + FR + stabiliser + LDH + FR*LDH + stabiliser*LDH
# filler + FR + stabiliser + spherical_filler + filler*FR + filler*stabiliser
# filler + FR + stabiliser + spherical_filler + filler*FR + filler*spherical_filler
# filler + FR + stabiliser + spherical_filler + filler*FR + FR*stabiliser
# filler + FR + stabiliser + spherical_filler + filler*FR + FR*spherical_filler
# filler + FR + stabiliser + spherical_filler + filler*FR + stabiliser*spherical_filler
# filler + FR + stabiliser + spherical_filler + filler*stabiliser + filler*spherical_filler
# filler + FR + stabiliser + spherical_filler + filler*stabiliser + FR*stabiliser
# filler + FR + stabiliser + spherical_filler + filler*stabiliser + FR*spherical_filler
# filler + FR + stabiliser + spherical_filler + filler*stabiliser + stabiliser*spherical_filler
# filler + FR + stabiliser + spherical_filler + filler*spherical_filler + FR*stabiliser
# filler + FR + stabiliser + spherical_filler + filler*spherical_filler + FR*spherical_filler
# filler + FR + stabiliser + spherical_filler + filler*spherical_filler + stabiliser*spherical_filler
# filler + FR + stabiliser + spherical_filler + FR*stabiliser + FR*spherical_filler
# filler + FR + stabiliser + spherical_filler + FR*stabiliser + stabiliser*spherical_filler
# filler + FR + stabiliser + spherical_filler + FR*spherical_filler + stabiliser*spherical_filler
# filler + FR + stabiliser + filler*FR + filler*stabiliser + FR*stabiliser
# filler + FR + DINP + LDH + spherical_filler + filler*FR
# filler + FR + DINP + LDH + spherical_filler + filler*DINP
# filler + FR + DINP + LDH + spherical_filler + filler*LDH
# filler + FR + DINP + LDH + spherical_filler + filler*spherical_filler
# filler + FR + DINP + LDH + spherical_filler + FR*DINP
# filler + FR + DINP + LDH + spherical_filler + FR*LDH
# filler + FR + DINP + LDH + spherical_filler + FR*spherical_filler
# filler + FR + DINP + LDH + spherical_filler + DINP*LDH
# filler + FR + DINP + LDH + spherical_filler + DINP*spherical_filler
# filler + FR + DINP + LDH + spherical_filler + LDH*spherical_filler
# filler + FR + DINP + LDH + filler*FR + filler*DINP
# filler + FR + DINP + LDH + filler*FR + filler*LDH
# filler + FR + DINP + LDH + filler*FR + FR*DINP
# filler + FR + DINP + LDH + filler*FR + FR*LDH
# filler + FR + DINP + LDH + filler*FR + DINP*LDH
# filler + FR + DINP + LDH + filler*DINP + filler*LDH
# filler + FR + DINP + LDH + filler*DINP + FR*DINP
# filler + FR + DINP + LDH + filler*DINP + FR*LDH
# filler + FR + DINP + LDH + filler*DINP + DINP*LDH
# filler + FR + DINP + LDH + filler*LDH + FR*DINP
# filler + FR + DINP + LDH + filler*LDH + FR*LDH
# filler + FR + DINP + LDH + filler*LDH + DINP*LDH
# filler + FR + DINP + LDH + FR*DINP + FR*LDH
# filler + FR + DINP + LDH + FR*DINP + DINP*LDH
# filler + FR + DINP + LDH + FR*LDH + DINP*LDH
# filler + FR + DINP + spherical_filler + filler*FR + filler*DINP
# filler + FR + DINP + spherical_filler + filler*FR + filler*spherical_filler
# filler + FR + DINP + spherical_filler + filler*FR + FR*DINP
# filler + FR + DINP + spherical_filler + filler*FR + FR*spherical_filler
# filler + FR + DINP + spherical_filler + filler*FR + DINP*spherical_filler
# filler + FR + DINP + spherical_filler + filler*DINP + filler*spherical_filler
# filler + FR + DINP + spherical_filler + filler*DINP + FR*DINP
# filler + FR + DINP + spherical_filler + filler*DINP + FR*spherical_filler
# filler + FR + DINP + spherical_filler + filler*DINP + DINP*spherical_filler
# filler + FR + DINP + spherical_filler + filler*spherical_filler + FR*DINP
# filler + FR + DINP + spherical_filler + filler*spherical_filler + FR*spherical_filler
# filler + FR + DINP + spherical_filler + filler*spherical_filler + DINP*spherical_filler
# filler + FR + DINP + spherical_filler + FR*DINP + FR*spherical_filler
# filler + FR + DINP + spherical_filler + FR*DINP + DINP*spherical_filler
# filler + FR + DINP + spherical_filler + FR*spherical_filler + DINP*spherical_filler
# filler + FR + DINP + filler*FR + filler*DINP + FR*DINP
# filler + FR + LDH + spherical_filler + filler*FR + filler*LDH
# filler + FR + LDH + spherical_filler + filler*FR + filler*spherical_filler
# filler + FR + LDH + spherical_filler + filler*FR + FR*LDH
# filler + FR + LDH + spherical_filler + filler*FR + FR*spherical_filler
# filler + FR + LDH + spherical_filler + filler*FR + LDH*spherical_filler
# filler + FR + LDH + spherical_filler + filler*LDH + filler*spherical_filler
# filler + FR + LDH + spherical_filler + filler*LDH + FR*LDH
# filler + FR + LDH + spherical_filler + filler*LDH + FR*spherical_filler
# filler + FR + LDH + spherical_filler + filler*LDH + LDH*spherical_filler
# filler + FR + LDH + spherical_filler + filler*spherical_filler + FR*LDH
# filler + FR + LDH + spherical_filler + filler*spherical_filler + FR*spherical_filler
# filler + FR + LDH + spherical_filler + filler*spherical_filler + LDH*spherical_filler
# filler + FR + LDH + spherical_filler + FR*LDH + FR*spherical_filler
# filler + FR + LDH + spherical_filler + FR*LDH + LDH*spherical_filler
# filler + FR + LDH + spherical_filler + FR*spherical_filler + LDH*spherical_filler
# filler + FR + LDH + filler*FR + filler*LDH + FR*LDH
# filler + FR + spherical_filler + filler*FR + filler*spherical_filler + FR*spherical_filler
# filler + stabiliser + DINP + LDH + spherical_filler + filler*stabiliser
# filler + stabiliser + DINP + LDH + spherical_filler + filler*DINP
# filler + stabiliser + DINP + LDH + spherical_filler + filler*LDH
# filler + stabiliser + DINP + LDH + spherical_filler + filler*spherical_filler
# filler + stabiliser + DINP + LDH + spherical_filler + stabiliser*DINP
# filler + stabiliser + DINP + LDH + spherical_filler + stabiliser*LDH
# filler + stabiliser + DINP + LDH + spherical_filler + stabiliser*spherical_filler
# filler + stabiliser + DINP + LDH + spherical_filler + DINP*LDH
# filler + stabiliser + DINP + LDH + spherical_filler + DINP*spherical_filler
# filler + stabiliser + DINP + LDH + spherical_filler + LDH*spherical_filler
# filler + stabiliser + DINP + LDH + filler*stabiliser + filler*DINP
# filler + stabiliser + DINP + LDH + filler*stabiliser + filler*LDH
# filler + stabiliser + DINP + LDH + filler*stabiliser + stabiliser*DINP
# filler + stabiliser + DINP + LDH + filler*stabiliser + stabiliser*LDH
# filler + stabiliser + DINP + LDH + filler*stabiliser + DINP*LDH
# filler + stabiliser + DINP + LDH + filler*DINP + filler*LDH
# filler + stabiliser + DINP + LDH + filler*DINP + stabiliser*DINP
# filler + stabiliser + DINP + LDH + filler*DINP + stabiliser*LDH
# filler + stabiliser + DINP + LDH + filler*DINP + DINP*LDH
# filler + stabiliser + DINP + LDH + filler*LDH + stabiliser*DINP
# filler + stabiliser + DINP + LDH + filler*LDH + stabiliser*LDH
# filler + stabiliser + DINP + LDH + filler*LDH + DINP*LDH
# filler + stabiliser + DINP + LDH + stabiliser*DINP + stabiliser*LDH
# filler + stabiliser + DINP + LDH + stabiliser*DINP + DINP*LDH
# filler + stabiliser + DINP + LDH + stabiliser*LDH + DINP*LDH
# filler + stabiliser + DINP + spherical_filler + filler*stabiliser + filler*DINP
# filler + stabiliser + DINP + spherical_filler + filler*stabiliser + filler*spherical_filler
# filler + stabiliser + DINP + spherical_filler + filler*stabiliser + stabiliser*DINP
# filler + stabiliser + DINP + spherical_filler + filler*stabiliser + stabiliser*spherical_filler
# filler + stabiliser + DINP + spherical_filler + filler*stabiliser + DINP*spherical_filler
# filler + stabiliser + DINP + spherical_filler + filler*DINP + filler*spherical_filler
# filler + stabiliser + DINP + spherical_filler + filler*DINP + stabiliser*DINP
# filler + stabiliser + DINP + spherical_filler + filler*DINP + stabiliser*spherical_filler
# filler + stabiliser + DINP + spherical_filler + filler*DINP + DINP*spherical_filler
# filler + stabiliser + DINP + spherical_filler + filler*spherical_filler + stabiliser*DINP
# filler + stabiliser + DINP + spherical_filler + filler*spherical_filler + stabiliser*spherical_filler
# filler + stabiliser + DINP + spherical_filler + filler*spherical_filler + DINP*spherical_filler
# filler + stabiliser + DINP + spherical_filler + stabiliser*DINP + stabiliser*spherical_filler
# filler + stabiliser + DINP + spherical_filler + stabiliser*DINP + DINP*spherical_filler
# filler + stabiliser + DINP + spherical_filler + stabiliser*spherical_filler + DINP*spherical_filler
# filler + stabiliser + DINP + filler*stabiliser + filler*DINP + stabiliser*DINP
# filler + stabiliser + LDH + spherical_filler + filler*stabiliser + filler*LDH
# filler + stabiliser + LDH + spherical_filler + filler*stabiliser + filler*spherical_filler
# filler + stabiliser + LDH + spherical_filler + filler*stabiliser + stabiliser*LDH
# filler + stabiliser + LDH + spherical_filler + filler*stabiliser + stabiliser*spherical_filler
# filler + stabiliser + LDH + spherical_filler + filler*stabiliser + LDH*spherical_filler
# filler + stabiliser + LDH + spherical_filler + filler*LDH + filler*spherical_filler
# filler + stabiliser + LDH + spherical_filler + filler*LDH + stabiliser*LDH
# filler + stabiliser + LDH + spherical_filler + filler*LDH + stabiliser*spherical_filler
# filler + stabiliser + LDH + spherical_filler + filler*LDH + LDH*spherical_filler
# filler + stabiliser + LDH + spherical_filler + filler*spherical_filler + stabiliser*LDH
# filler + stabiliser + LDH + spherical_filler + filler*spherical_filler + stabiliser*spherical_filler
# filler + stabiliser + LDH + spherical_filler + filler*spherical_filler + LDH*spherical_filler
# filler + stabiliser + LDH + spherical_filler + stabiliser*LDH + stabiliser*spherical_filler
# filler + stabiliser + LDH + spherical_filler + stabiliser*LDH + LDH*spherical_filler
# filler + stabiliser + LDH + spherical_filler + stabiliser*spherical_filler + LDH*spherical_filler
# filler + stabiliser + LDH + filler*stabiliser + filler*LDH + stabiliser*LDH
# filler + stabiliser + spherical_filler + filler*stabiliser + filler*spherical_filler + stabiliser*spherical_filler
# filler + DINP + LDH + spherical_filler + filler*DINP + filler*LDH
# filler + DINP + LDH + spherical_filler + filler*DINP + filler*spherical_filler
# filler + DINP + LDH + spherical_filler + filler*DINP + DINP*LDH
# filler + DINP + LDH + spherical_filler + filler*DINP + DINP*spherical_filler
# filler + DINP + LDH + spherical_filler + filler*DINP + LDH*spherical_filler
# filler + DINP + LDH + spherical_filler + filler*LDH + filler*spherical_filler
# filler + DINP + LDH + spherical_filler + filler*LDH + DINP*LDH
# filler + DINP + LDH + spherical_filler + filler*LDH + DINP*spherical_filler
# filler + DINP + LDH + spherical_filler + filler*LDH + LDH*spherical_filler
# filler + DINP + LDH + spherical_filler + filler*spherical_filler + DINP*LDH
# filler + DINP + LDH + spherical_filler + filler*spherical_filler + DINP*spherical_filler
# filler + DINP + LDH + spherical_filler + filler*spherical_filler + LDH*spherical_filler
# filler + DINP + LDH + spherical_filler + DINP*LDH + DINP*spherical_filler
# filler + DINP + LDH + spherical_filler + DINP*LDH + LDH*spherical_filler
# filler + DINP + LDH + spherical_filler + DINP*spherical_filler + LDH*spherical_filler
# filler + DINP + LDH + filler*DINP + filler*LDH + DINP*LDH
# filler + DINP + spherical_filler + filler*DINP + filler*spherical_filler + DINP*spherical_filler
# filler + LDH + spherical_filler + filler*LDH + filler*spherical_filler + LDH*spherical_filler
# FR + stabiliser + DINP + LDH + spherical_filler + FR*stabiliser
# FR + stabiliser + DINP + LDH + spherical_filler + FR*DINP
# FR + stabiliser + DINP + LDH + spherical_filler + FR*LDH
# FR + stabiliser + DINP + LDH + spherical_filler + FR*spherical_filler
# FR + stabiliser + DINP + LDH + spherical_filler + stabiliser*DINP
# FR + stabiliser + DINP + LDH + spherical_filler + stabiliser*LDH
# FR + stabiliser + DINP + LDH + spherical_filler + stabiliser*spherical_filler
# FR + stabiliser + DINP + LDH + spherical_filler + DINP*LDH
# FR + stabiliser + DINP + LDH + spherical_filler + DINP*spherical_filler
# FR + stabiliser + DINP + LDH + spherical_filler + LDH*spherical_filler
# FR + stabiliser + DINP + LDH + FR*stabiliser + FR*DINP
# FR + stabiliser + DINP + LDH + FR*stabiliser + FR*LDH
# FR + stabiliser + DINP + LDH + FR*stabiliser + stabiliser*DINP
# FR + stabiliser + DINP + LDH + FR*stabiliser + stabiliser*LDH
# FR + stabiliser + DINP + LDH + FR*stabiliser + DINP*LDH
# FR + stabiliser + DINP + LDH + FR*DINP + FR*LDH
# FR + stabiliser + DINP + LDH + FR*DINP + stabiliser*DINP
# FR + stabiliser + DINP + LDH + FR*DINP + stabiliser*LDH
# FR + stabiliser + DINP + LDH + FR*DINP + DINP*LDH
# FR + stabiliser + DINP + LDH + FR*LDH + stabiliser*DINP
# FR + stabiliser + DINP + LDH + FR*LDH + stabiliser*LDH
# FR + stabiliser + DINP + LDH + FR*LDH + DINP*LDH
# FR + stabiliser + DINP + LDH + stabiliser*DINP + stabiliser*LDH
# FR + stabiliser + DINP + LDH + stabiliser*DINP + DINP*LDH
# FR + stabiliser + DINP + LDH + stabiliser*LDH + DINP*LDH
# FR + stabiliser + DINP + spherical_filler + FR*stabiliser + FR*DINP
# FR + stabiliser + DINP + spherical_filler + FR*stabiliser + FR*spherical_filler
# FR + stabiliser + DINP + spherical_filler + FR*stabiliser + stabiliser*DINP
# FR + stabiliser + DINP + spherical_filler + FR*stabiliser + stabiliser*spherical_filler
# FR + stabiliser + DINP + spherical_filler + FR*stabiliser + DINP*spherical_filler
# FR + stabiliser + DINP + spherical_filler + FR*DINP + FR*spherical_filler
# FR + stabiliser + DINP + spherical_filler + FR*DINP + stabiliser*DINP
# FR + stabiliser + DINP + spherical_filler + FR*DINP + stabiliser*spherical_filler
# FR + stabiliser + DINP + spherical_filler + FR*DINP + DINP*spherical_filler
# FR + stabiliser + DINP + spherical_filler + FR*spherical_filler + stabiliser*DINP
# FR + stabiliser + DINP + spherical_filler + FR*spherical_filler + stabiliser*spherical_filler
# FR + stabiliser + DINP + spherical_filler + FR*spherical_filler + DINP*spherical_filler
# FR + stabiliser + DINP + spherical_filler + stabiliser*DINP + stabiliser*spherical_filler
# FR + stabiliser + DINP + spherical_filler + stabiliser*DINP + DINP*spherical_filler
# FR + stabiliser + DINP + spherical_filler + stabiliser*spherical_filler + DINP*spherical_filler
# FR + stabiliser + DINP + FR*stabiliser + FR*DINP + stabiliser*DINP
# FR + stabiliser + LDH + spherical_filler + FR*stabiliser + FR*LDH
# FR + stabiliser + LDH + spherical_filler + FR*stabiliser + FR*spherical_filler
# FR + stabiliser + LDH + spherical_filler + FR*stabiliser + stabiliser*LDH
# FR + stabiliser + LDH + spherical_filler + FR*stabiliser + stabiliser*spherical_filler
# FR + stabiliser + LDH + spherical_filler + FR*stabiliser + LDH*spherical_filler
# FR + stabiliser + LDH + spherical_filler + FR*LDH + FR*spherical_filler
# FR + stabiliser + LDH + spherical_filler + FR*LDH + stabiliser*LDH
# FR + stabiliser + LDH + spherical_filler + FR*LDH + stabiliser*spherical_filler
# FR + stabiliser + LDH + spherical_filler + FR*LDH + LDH*spherical_filler
# FR + stabiliser + LDH + spherical_filler + FR*spherical_filler + stabiliser*LDH
# FR + stabiliser + LDH + spherical_filler + FR*spherical_filler + stabiliser*spherical_filler
# FR + stabiliser + LDH + spherical_filler + FR*spherical_filler + LDH*spherical_filler
# FR + stabiliser + LDH + spherical_filler + stabiliser*LDH + stabiliser*spherical_filler
# FR + stabiliser + LDH + spherical_filler + stabiliser*LDH + LDH*spherical_filler
# FR + stabiliser + LDH + spherical_filler + stabiliser*spherical_filler + LDH*spherical_filler
# FR + stabiliser + LDH + FR*stabiliser + FR*LDH + stabiliser*LDH
# FR + stabiliser + spherical_filler + FR*stabiliser + FR*spherical_filler + stabiliser*spherical_filler
# FR + DINP + LDH + spherical_filler + FR*DINP + FR*LDH
# FR + DINP + LDH + spherical_filler + FR*DINP + FR*spherical_filler
# FR + DINP + LDH + spherical_filler + FR*DINP + DINP*LDH
# FR + DINP + LDH + spherical_filler + FR*DINP + DINP*spherical_filler
# FR + DINP + LDH + spherical_filler + FR*DINP + LDH*spherical_filler
# FR + DINP + LDH + spherical_filler + FR*LDH + FR*spherical_filler
# FR + DINP + LDH + spherical_filler + FR*LDH + DINP*LDH
# FR + DINP + LDH + spherical_filler + FR*LDH + DINP*spherical_filler
# FR + DINP + LDH + spherical_filler + FR*LDH + LDH*spherical_filler
# FR + DINP + LDH + spherical_filler + FR*spherical_filler + DINP*LDH
# FR + DINP + LDH + spherical_filler + FR*spherical_filler + DINP*spherical_filler
# FR + DINP + LDH + spherical_filler + FR*spherical_filler + LDH*spherical_filler
# FR + DINP + LDH + spherical_filler + DINP*LDH + DINP*spherical_filler
# FR + DINP + LDH + spherical_filler + DINP*LDH + LDH*spherical_filler
# FR + DINP + LDH + spherical_filler + DINP*spherical_filler + LDH*spherical_filler
# FR + DINP + LDH + FR*DINP + FR*LDH + DINP*LDH
# FR + DINP + spherical_filler + FR*DINP + FR*spherical_filler + DINP*spherical_filler
# FR + LDH + spherical_filler + FR*LDH + FR*spherical_filler + LDH*spherical_filler
# stabiliser + DINP + LDH + spherical_filler + stabiliser*DINP + stabiliser*LDH
# stabiliser + DINP + LDH + spherical_filler + stabiliser*DINP + stabiliser*spherical_filler
# stabiliser + DINP + LDH + spherical_filler + stabiliser*DINP + DINP*LDH
# stabiliser + DINP + LDH + spherical_filler + stabiliser*DINP + DINP*spherical_filler
# stabiliser + DINP + LDH + spherical_filler + stabiliser*DINP + LDH*spherical_filler
# stabiliser + DINP + LDH + spherical_filler + stabiliser*LDH + stabiliser*spherical_filler
# stabiliser + DINP + LDH + spherical_filler + stabiliser*LDH + DINP*LDH
# stabiliser + DINP + LDH + spherical_filler + stabiliser*LDH + DINP*spherical_filler
# stabiliser + DINP + LDH + spherical_filler + stabiliser*LDH + LDH*spherical_filler
# stabiliser + DINP + LDH + spherical_filler + stabiliser*spherical_filler + DINP*LDH
# stabiliser + DINP + LDH + spherical_filler + stabiliser*spherical_filler + DINP*spherical_filler
# stabiliser + DINP + LDH + spherical_filler + stabiliser*spherical_filler + LDH*spherical_filler
# stabiliser + DINP + LDH + spherical_filler + DINP*LDH + DINP*spherical_filler
# stabiliser + DINP + LDH + spherical_filler + DINP*LDH + LDH*spherical_filler
# stabiliser + DINP + LDH + spherical_filler + DINP*spherical_filler + LDH*spherical_filler
# stabiliser + DINP + LDH + stabiliser*DINP + stabiliser*LDH + DINP*LDH
# stabiliser + DINP + spherical_filler + stabiliser*DINP + stabiliser*spherical_filler + DINP*spherical_filler
# stabiliser + LDH + spherical_filler + stabiliser*LDH + stabiliser*spherical_filler + LDH*spherical_filler
# DINP + LDH + spherical_filler + DINP*LDH + DINP*spherical_filler + LDH*spherical_filler
# ____________________
# time 0.769999980927
# models 777
