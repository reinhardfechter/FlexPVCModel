# %%
from data_processing_pipeline import get_all_top_models
# Out:
# C:\Users\Reinhard\AppData\Local\Continuum\Anaconda\lib\site-packages\IPython\html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
get_all_top_models()
# Out:
# Accessed db: Single_Value_Database
# Accessed db: Only_Top_Models
# Scoring results not available for colour YI with 6 terms
# Scoring results not available for colour YI with 7 terms
# Scoring results not available for colour YI with 8 terms
# Scoring results not available for colour YI with 9 terms
# Scoring results not available for colour YI with 10 terms
# Scoring results not available for colour YI with 11 terms
# Scoring results not available for colour YI with 12 terms
# Scoring results not available for colour YI with 13 terms
# Scoring results not available for colour YI with 14 terms
# Scoring results not available for colour YI with 15 terms
# Scoring results not available for colour YI with 16 terms
# Scoring results not available for colour YI with 17 terms
# Scoring results not available for colour YI with 18 terms
# Scoring results not available for colour YI with 19 terms
# Scoring results not available for colour YI with 20 terms
# ...
