# %%
from datahandling import access_other_db

# %%
db = access_other_db(2)
# Out:
# Accessed db: Fitting_Results

# %%
p_val_1 = 0
for code in range(28):
    for i in db.all():
        model_code = i['model_code']
        p_val = i['p_val']
        if code in model_code:
            index = model_code.index(code)
            if p_val[index] != p_val_1:
                p_val_1 = p_val[index] 
                print p_val_1
    
    print '_________________'
# Out:
# 0.8877830708
# _________________
# 0.2362272998
# _________________
# 0.5038708254
# _________________
# 0.4961106904
# _________________
# 0.535729641
# _________________
# 0.806213308
# _________________
# 0.5504559159
# _________________
# 0.1029714814
# _________________
# 0.6507676411
# _________________
# 0.4765085899
# _________________
# 0.1885668635
# _________________
# 0.8766481487
# _________________
# 0.5214292908
# _________________
# 0.2983939881
# _________________
# 0.0267984802
# _________________
# 0.7977711913
# _________________
# 0.3800549566
# _________________
# 0.6800199767
# _________________
# 0.851911077
# _________________
# 0.2095398911
# _________________
# 0.959005516
# _________________
# 0.9348846111
# _________________
# 0.1013142919
# _________________
# 0.7084293696
# _________________
# 0.0149088777
# _________________
# 0.3423015555
# _________________
# 0.6535657534
# _________________
# 0.5981472908
# _________________

# %%
p_val_1 = 0
for code in range(28):
    for i in db.all():
        model_code = i['model_code']
        p_val = i['p_val']
        if code in model_code:
            index = model_code.index(code)
            if p_val[index] != p_val_1:
                p_val_1 = p_val[index] 
                print p_val_1
    
    print '_________________'
# Out:
# 0.4385668981
# _________________
# 0.0284478199
# _________________
# 0.7479755411
# _________________
# 0.2892166407
# _________________
# 4.85664e-05
# _________________
# 0.6926861759
# _________________
# 0.5534795515
# _________________
# 0.020159734
# _________________
# 0.7103052421
# _________________
# 0.4068222275
# _________________
# 0.0001854982
# _________________
# 0.969359905
# _________________
# 0.4339951593
# _________________
# 0.0361602421
# _________________
# 0.2475139783
# _________________
# 0.325489236
# _________________
# 0.0990206075
# _________________
# 0.0587346525
# _________________
# 0.823943023
# _________________
# 0.1853043477
# _________________
# 0.8146324649
# _________________
# 0.858450075
# _________________
# 0.0008737735
# _________________
# 0.9840590434
# _________________
# 0.9685552644
# _________________
# 0.002920884
# _________________
# 0.3435344631
# _________________
# 0.9326193469
# _________________
